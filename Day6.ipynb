# %% [markdown]
# Python File Handling

# %%
myfile = open("Sagar.txt",'a')
myfile.write("\nIs this text printing on the Txt file ?")
myfile.close()

# %%
myfile2 =  open("Sagar.txt",'r')
data = myfile2.read()
print(data)
myfile2.close()
# Out:
# Is this text printing on the Txt file ?Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
# Is this text printing on the Txt file ?
